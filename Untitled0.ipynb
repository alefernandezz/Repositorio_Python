# %%
lista1=[1,12,123]
lista2=["Bye","Ciao","Agur","Adieu"]
lista1.append(1234)
lista1.append("hola")
print(lista1)
lista2.append("adios")
lista2.append(1234)
lista2
# Out:
# [1, 12, 123, 1234, 'hola']
# ['Bye', 'Ciao', 'Agur', 'Adieu', 'adios', 1234]

# %%
a = 10
b = -5
c = "Hola"
d = [1,2,3]
e= (4,5,6) 
print(e+(7,8,9))
# Out:
# (4, 5, 6, 7, 8, 9)

# %%
nota_1 = 3
nota_1 *= 0.15
nota_2 = 7
nota_2 *= 0.35
nota_3 = 9
nota_3 *= 0.50
nota_med=(nota_1+nota_2+nota_3)/3
print("La nota media es: ",nota_med)
# Out:
# La nota media es:  2.4666666666666663

# %%
matriz = [ 
  [1, 5, 1],
   [2, 1, 2],
   [3, 0, 1],
   [1, 4, 4]
]
fila_1 = [ 
    sum([1, 5, 1]),
]
fila_2 = [
    sum([2, 1, 2]),
]
fila_3 = [
    sum([3, 0, 1]),
]
fila_4 = [
    sum([1, 4, 4])
]

print(matriz[0]+fila_1)
print(matriz[1]+fila_2)
print(matriz[2]+fila_3)
print(matriz[3]+fila_4)
# Out:
# [1, 5, 1, 7]
# [2, 1, 2, 5]
# [3, 0, 1, 4]
# [1, 4, 4, 9]

# %%
numero_1=(int(input("Ingrese un numero entero ")))
numero_2=(int(input("Ingrese un numero entero")))
resto=(numero_1%numero_2)
if (resto == 0):
  print("El resultado de la division de los numeros es exacta")
else:
  print("El resultado de la division de los numeros no es exacta")
# Out:
# Ingrese un numero entero 10
# Ingrese un numero entero2
# El resultado de la division de los numeros es exacta

# %%
nro1=int(input("Ingrese el primer numero"))
nro2=int(input("Ingrese el segundo numero"))
nro3=int(input("Ingrese el tercer numero"))
if (nro1 == nro2 and nro2 == nro3):
  print("Los tres numeros son iguales")
if ((nro1 == nro2 and nro2 != nro3) or (nro1 == nro3 and nro2 != nro3) or (nro2 == nro3 and nro1 != nro2)):
    print("Dos numeros son iguales")
if (nro1 != nro2 and nro2 != nro3 and nro1 != nro3):
    print("Los tres numeros son distintos")
# Out:
# Ingrese el primer numero1
# Ingrese el segundo numero2
# Ingrese el tercer numero3
# Los tres numeros son distintos

# %% [markdown]
# Falso
# Verdadero
# Verdadero
# Falso

# %%
hola="Hola Mendoza'
print(hola)
# Out:
#   File "<ipython-input-4-99df0c2ba055>", line 1
#     hola="Hola Mendoza'
#                        ^
# SyntaxError: EOL while scanning string literal

# %%
string='''?
!
#
%
('''
print(string)
# Out:
# ?
# !
# #
# %
# (
