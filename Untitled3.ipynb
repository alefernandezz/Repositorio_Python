# %%
def suma(num1,num2):
  return num2+num1
num3= suma("5","10")
print(num3)
# Out:
# 105

# %%
class calculadora:
  def suma(num1,num2):
    return num1+num2

calculator = calculadora
calculator.suma(1,2)
# Out:
# 3
