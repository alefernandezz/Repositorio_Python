# %%
class Perro:
  especie="Mamifero" #Esto es un atributo de la clase perro
#init es un constructor definimos un metodo en la clase
#self se usa para representar la instancia de una clase
  def __init__(self,nombre,raza):
    self.nombre=nombre
    self.raza=raza

perro1= Perro("Vitto","Pug")

print(f"Su nombre es: {perro1.nombre}")
print(f"Su raza es: {perro1.raza}")
print(f"Es un: {perro1.especie}")
# Out:
# Su nombre es: Vitto
# Su raza es: Pug
# Es un: Mamifero

# %%
class Persona:
  #atributo de clase persona color de pelo y altura
  altura="1,80m"
  color_pelo="Marrón"
  #Ahora agregamos 3 atributos de instancia
  def __init__(self,nombre,edad,sexo):
    self.nombre=nombre
    self.edad=edad
    self.sexo=sexo
Persona1= Persona("Alejandro","25","Masculino")
Persona2= Persona("Carolina","23","Femenino")
print(f"Su nombre es: {Persona1.nombre}")
print(f"Su edad es: {Persona1.edad}")
print(f"Su sexo es: {Persona1.sexo}")
print(f"Su altura es {Persona.altura}")
print(f"Su colo de pelo es: {Persona.color_pelo}")
# Out:
# Su nombre es: Alejandro
# Su edad es: 25
# Su sexo es: Masculino
# Su altura es 1,80m
# Su colo de pelo es: Marrón

# %%
class Cuenta:
  #necesito un atributo de titular de la cuenta y uno para la cantidad
  def __init__(self,titular,cantidad):
    self.titular=titular
    self.cantidad=cantidad
  #necesito definir mostrar() como metodo
  def mostrar(self):
    print("El titular de la cuenta es Lucas y tiene $23.000,00 en su cuenta")
  def ingresar(self,cantidad):
    if (cantidad < 0):
      pass
    else:
      cantidad=23000+cantidad
      print(f"Ahora tiene: ${cantidad} en su cuenta")
  def retirar(self,cantidad):
    cantidad=31000-cantidad
    print(f"Ahora tiene: ${cantidad} en su cuenta")

cuenta1=Cuenta("Lucas",23000)
print(f"El titular de la cuenta es: {cuenta1.titular}")
print(f"El titular {cuenta1.titular} tiene ${cuenta1.cantidad} en su cuenta")
cuenta1.mostrar()
cuenta1.ingresar(8000)
cuenta1.retirar(5000)
# Out:
# El titular de la cuenta es: Lucas
# El titular Lucas tiene $23000 en su cuenta
# El titular de la cuenta es Lucas y tiene $23.000,00 en su cuenta
# Ahora tiene: $31000 en su cuenta
# Ahora tiene: $26000 en su cuenta
