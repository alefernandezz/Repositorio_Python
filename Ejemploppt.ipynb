# %%
def par_imp(nro):
  if (nro%2 == 0):
    nro="par"
  else:
    nro="impar"
  return (nro)
n=int(input("Ingrese un numero por favor "))
func = par_imp(n)
print("El numero ingresado es: ",func)
# Out:
# Ingrese un numero por favor 4
# El numero ingresado es:  par

# %%
def ano_bisiesto(anio):
  if ((anio%4 == 0 and anio%400 == 0) and (anio%100 != 0) or ((anio%4 == 0 or anio%400 == 0) and (anio%100 != 0)) or (anio%4 == 0 and anio%400 == 0) and (anio%100 == 0)):
    #revisar condiciones!!!
    anio="bisiesto"
  else:
    anio="no bisiesto"
  return(anio)
year=int(input("Ingrese un año por favor "))
#llamamos a la funcion anio_bisiesto
calendar = ano_bisiesto(year)
print("El año ingresado es: ",calendar)
# Out:
# Ingrese un año por favor 2012
# El año ingresado es:  bisiesto

# %%
def lee_anio():
    #No le pasamos ningun parametro para que inicie la funcion al ser invocada
    #Solicita un valor entero y lo devuelve.
    #Mientras el valor ingresado no sea entero, vuelve a solicitarlo
    while True:
        year = input("Ingrese un año por favor: ")
        try:
            year = int(year)
            return year
        except ValueError:
            print ("ATENCIÓN: Debe ingresar un número entero.")
def ano_bisiesto(anio):
  if ((anio%4 == 0 and anio%400 == 0) and (anio%100 != 0) or ((anio%4 == 0 or anio%400 == 0) and (anio%100 != 0)) or (anio%4 == 0 and anio%400 == 0) and (anio%100 == 0)):
    #revisamos que cumpla las condiciones para ser bisiesto o no
    anio="bisiesto"
  else:
    anio="no bisiesto"
  return(anio)
#llamamos a primero a la funcion lee_anio para comprobar que se ingrese un entero
#y despues llamamos la funcion ano_bisiesto para saber si el año es bisiesto o no
anio_comp= lee_anio()
calendar = ano_bisiesto(anio_comp)
print("El año ingresado es: ",calendar)
# Out:
# Ingrese un año por favor: 2012
# El año ingresado es:  bisiesto
