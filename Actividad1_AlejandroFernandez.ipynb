# %%
#Actividad 1
#La nota_1 tiene un peso del 40% en la nota final
nota_1=int(input("Ingrese la primer nota del alumno: "))
nota_1=nota_1*0.40
#La nota_2 tiene un peso del 60% en la nota final
nota_2=int(input("Ingrese la segunda nota del alumno: "))
nota_2=nota_2*0.60
promedio=int(nota_1 + nota_2) #Agregamos int para que la salida sea siempre la parte entera
if promedio >=7 :
    print("Felicidades está aprobado con ",promedio)
else:
    print("A seguir estudiando, su nota final es ",promedio)
# Out:
# Ingrese la primer nota del alumno: 6
# Ingrese la segunda nota del alumno: 8
# Felicidades está aprobado con  7
